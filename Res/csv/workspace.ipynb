# %%
import pandas as pd
from pathlib import Path
anime_df = pd.read_csv("Anime.csv")

# %%
anime_df
# Out:
#                                title                     title_english  \
# 0                 Shingeki no Kyojin                   Attack on Titan
# 1                         Death Note                        Death Note
# 2   Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood
# 3                      One Punch Man                     One Punch Man
# 4                   Kimetsu no Yaiba    Demon Slayer: Kimetsu no Yaiba
# 5                   Sword Art Online                  Sword Art Online
# 6              Boku no Hero Academia                  My Hero Academia
# 7             Hunter x Hunter (2011)                   Hunter x Hunter
# 8                             Naruto                            Naruto
# 9                        Tokyo Ghoul                       Tokyo Ghoul
# 10                    Kimi no Na wa.                        Your Name.
# 11       Shingeki no Kyojin Season 2          Attack on Titan Season 2
# ...

# %%
anime_df.head()
anime_df.tail()

anime_df.shape

anime_df.columns

anime_df.info()

anime_df.describe()

# %%
# anime_df[anime_df['favorites'] == anime_df['favorites'].max()]
# anime_df.loc[anime_df['favorites'].argmax()]

anime_df.loc[anime_df["episodes"].argmin()]
# Out:
# title                             One Piece
# title_english                     One Piece
# status                     Currently Airing
# episodes                                  0
# rating            PG-13 - Teens 13 or older
# rank                                     52
# popularity                               17
# members                             2548930
# favorites                            239752
# score                                  8.73
# scored_by                           1449377
# genres           Action, Adventure, Fantasy
# Name: 16, dtype: object

# %%
anime_df
# Out:
#                                title                     title_english  \
# 0                 Shingeki no Kyojin                   Attack on Titan
# 1                         Death Note                        Death Note
# 2   Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood
# 3                      One Punch Man                     One Punch Man
# 4                   Kimetsu no Yaiba    Demon Slayer: Kimetsu no Yaiba
# 5                   Sword Art Online                  Sword Art Online
# 6              Boku no Hero Academia                  My Hero Academia
# 7             Hunter x Hunter (2011)                   Hunter x Hunter
# 8                             Naruto                            Naruto
# 9                        Tokyo Ghoul                       Tokyo Ghoul
# 10                    Kimi no Na wa.                        Your Name.
# 11       Shingeki no Kyojin Season 2          Attack on Titan Season 2
# ...

# %%
print(anime_df[anime_df['episodes'] == 12].index[0])
# Out:
# 3

# %%
anime_title = "Naruto"
row = anime_df[anime_df['title'] == anime_title].index[0]
print(anime_df.iloc[row])
col =  'score'
anime_df.at[row,col] = 10
print(anime_df.iloc[row])
# Out:
# title                                Naruto
# title_english                        Naruto
# status                      Finished Airing
# episodes                                220
# rating            PG-13 - Teens 13 or older
# rank                                    674
# popularity                                9
# members                             3006981
# favorites                             83595
# score                                  8.01
# scored_by                           2070000
# genres           Action, Adventure, Fantasy
# Name: 8, dtype: object
# title                                Naruto
# title_english                        Naruto
# status                      Finished Airing
# episodes                                220
# rating            PG-13 - Teens 13 or older
# rank                                    674
# popularity                                9
# members                             3006981
# favorites                             83595
# ...

# %%
anime_df
# Out:
#                                title                     title_english  \
# 0                 Shingeki no Kyojin                   Attack on Titan
# 1                         Death Note                        Death Note
# 2   Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood
# 3                      One Punch Man                     One Punch Man
# 4                   Kimetsu no Yaiba    Demon Slayer: Kimetsu no Yaiba
# 5                   Sword Art Online                  Sword Art Online
# 6              Boku no Hero Academia                  My Hero Academia
# 7             Hunter x Hunter (2011)                   Hunter x Hunter
# 8                             Naruto                            Naruto
# 9                        Tokyo Ghoul                       Tokyo Ghoul
# 10                    Kimi no Na wa.                        Your Name.
# 11       Shingeki no Kyojin Season 2          Attack on Titan Season 2
# ...

# %% [markdown]
# # Making visualisations with matplotlib and seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sorted_df = anime_df.sort_values(by='episodes')

plt.bar(sorted_df.title,sorted_df.episodes)
plt.xticks(rotation=90)
plt.grid()

# %%
df_view = anime_df#anime_df[anime_df['rank']]
sns.scatterplot(data=df_view, x='score', y='rank', hue='title', size='score')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout()
